# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img = mpimg.imread('primero.png')

# Display the image with axes
plt.imshow(img)
plt.axis('on')  # Turn on the axis
plt.show()
